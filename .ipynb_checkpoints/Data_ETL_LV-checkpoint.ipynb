# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading the file
df_LV_Canada = pd.read_csv('data/df_LV_Canada.csv')
df_LV_UK = pd.read_csv('data/df_LV_UK.csv')

# %%
df_LV_Canada
# Out:
#       Unnamed: 0   website_name competence_date country_code currency_code  \
# 0              0  Louis Vuitton      2023-11-17          CAN           CAD
# 1              1  Louis Vuitton      2023-11-17          CAN           CAD
# 2              2  Louis Vuitton      2023-11-17          CAN           CAD
# 3              3  Louis Vuitton      2023-11-17          CAN           CAD
# 4              4  Louis Vuitton      2023-11-17          CAN           CAD
# ...          ...            ...             ...          ...           ...
# 8146        8146  Louis Vuitton      2023-11-17          CAN           CAD
# 8147        8147  Louis Vuitton      2023-11-17          CAN           CAD
# 8148        8148  Louis Vuitton      2023-11-17          CAN           CAD
# 8149        8149  Louis Vuitton      2023-11-17          CAN           CAD
# 8150        8150  Louis Vuitton      2023-11-17          CAN           CAD
#
#               brand category1_code category2_code  \
# 0     LOUIS VUITTON          WOMEN          SHOES
# 1     LOUIS VUITTON          WOMEN    ACCESSORIES
# 2     LOUIS VUITTON          WOMEN       HANDBAGS
# 3     LOUIS VUITTON          WOMEN       HANDBAGS
# 4     LOUIS VUITTON            NEW      FOR WOMEN
# ...             ...            ...            ...
# 8146  LOUIS VUITTON          WOMEN    ACCESSORIES
# 8147  LOUIS VUITTON          WOMEN       HANDBAGS
# 8148  LOUIS VUITTON          WOMEN       HANDBAGS
# 8149  LOUIS VUITTON          WOMEN       HANDBAGS
# 8150  LOUIS VUITTON          WOMEN       HANDBAGS
#
#                     category3_code           product_code  \
# 0                         SNEAKERS  NVPROD3940098V/1ABD7F
# 1                   THE ESSENTIALS  NVPROD3940113V/M78897
# 2                            TWIST  NVPROD4230119V/M21554
# 3     SHOULDER AND CROSS BODY BAGS  NVPROD4230135V/M22368
# 4                  NEW THIS SEASON  NVPROD4700203V/1AC1K2
# ...                            ...                    ...
# 8146                         BELTS  NVPROD4120015V/M0659U
# 8147  SHOULDER AND CROSS BODY BAGS  NVPROD4120016V/M46421
# 8148  SHOULDER AND CROSS BODY BAGS  NVPROD4120017V/M46425
# 8149                         TOTES  NVPROD4120028V/M46381
# 8150  SHOULDER AND CROSS BODY BAGS  NVPROD4120038V/M46431
#
#                                                   title  \
# 0                         LV x YK LV Squad Sneaker Boot
# 1                              LV Essential Shine Scarf
# 2                                              Twist MM
# 3                                           Key Bell XL
# 4                                Animal Sequin T-Shirt
# ...                                                 ...
# 8146  LV x YK LV Initiales 30mm Reversible Infinity ...
# 8147                 LV x YK Multi Pochette Accessoires
# 8148                      LV x YK Speedy Bandoulière 20
# 8149                               LV x YK Neverfull MM
# 8150                                   LV x YK Alma BB​
#
#                                                 itemurl  \
# 0     https://ca.louisvuitton.com/eng-ca/products/lv...
# 1     https://ca.louisvuitton.com/eng-ca/products/lv...
# 2     https://ca.louisvuitton.com/eng-ca/products/tw...
# 3     https://ca.louisvuitton.com/eng-ca/products/ke...
# 4     https://ca.louisvuitton.com/eng-ca/products/t-...
#dropping the unnamed: 0 column as it is duplicate
df_LV_Canada = df_LV_Canada.drop(columns=['Unnamed: 0'])
df_LV_UK = df_LV_UK.drop(columns=['Unnamed: 0'])

# %%
duplicate_rows_canada = df_LV_Canada.duplicated().sum()
print("Number of duplicate rows in LV Canada:", duplicate_rows_canada)

duplicate_rows_uk = df_LV_Canada.duplicated().sum()
print("Number of duplicate rows in LV UK:", duplicate_rows_uk)
# Out:
# Number of duplicate rows in LV Canada: 0
# Number of duplicate rows in LV UK: 0

# %%
 #find the lowest value in column 'full_price'
lowest_value_LV_Canada = df_LV_Canada['full_price'].min()
print("Lowest Value LV Canada Product:", lowest_value_LV_Canada , "Dollar(Cad)")

lowest_value_LV_UK = df_LV_UK['full_price'].min()
print("Lowest Value LV UK Product:", lowest_value_LV_UK , "Pounds")

# Find the highest value in column 'full_price'
highest_value_LV_Canada = df_LV_Canada['full_price'].max()
print("Highest Value LV Product:", highest_value_LV_Canada , "Dollar(Cad)")

lowest_value_LV_UK = df_LV_UK['full_price'].max()
print("Lowest Value LV UK Product:", lowest_value_LV_UK , "Pounds")
# Out:
# Lowest Value LV Canada Product: 42.0 Dollar(Cad)
# Lowest Value LV UK Product: 17.0 Pounds
# Highest Value LV Product: 370000.0 Dollar(Cad)
# Lowest Value LV UK Product: 218000.0 Pounds

# %%
# checking which products comes in lowest value range to see the outliers
lowest_value_product_LV = df_LV_Canada[df_LV_Canada['full_price'] < 200]
lowest_value_product_LV.groupby(['category2_code']).agg({"full_price": "mean"})
# Out:
#                           full_price
# category2_code
# ACCESSORIES               180.000000
# BOOKS AND STATIONERY       66.870370
# COLLECTIONS               165.000000
# FOR MEN                    69.000000
# FOR WOMEN                  93.500000
# GIFT SELECTION FOR MEN     65.000000
# GIFT SELECTION FOR WOMEN   65.000000
# HIGHLIGHTS                156.666667
# LOUIS VUITTON COLORMANIA   42.000000
# LV SKI                     65.000000

# %%
# checking which products comes in lowest value range to see the outliers
lowest_value_product_LV_UK = df_LV_UK[df_LV_UK['full_price'] < 200]
lowest_value_product_LV_UK.groupby(['category2_code']).agg({"full_price": "mean"})
# Out:
#                                    full_price
# category2_code
# ACCESSORIES                        182.587719
# BOOKS AND STATIONERY                53.926316
# COLLECTIONS                        126.315789
# FASHION JEWELLERY                  195.000000
# FOR MEN                            189.444444
# FOR WOMEN                          190.000000
# GIFT SELECTION FOR MEN              46.000000
# GIFTS FOR HER                      190.000000
# HIGH TECH OBJECTS AND ACCESSORIES  145.000000
# HIGHLIGHTS                         105.250000
# HOME                               150.000000
# LOUIS VUITTON COLOURMANIA           35.800000
# LV SKI                              46.000000
# NEW FORMAL                         179.000000
# TRADITIONAL WATCHES                 66.000000
# WALLETS AND SMALL LEATHER GOODS    189.166667

# %%
# checking which products comes in highest value range to see the outliers
highest_value_product_LV = df_LV_Canada[df_LV_Canada['full_price'] >= 350000]
highest_value_product_LV.groupby(['category2_code']).agg({"full_price": "mean"})
# Out:
#                    full_price
# category2_code
# TRUNKS AND TRAVEL    370000.0

# %%
# checking which products comes in highest value range to see the outliers
highest_value_product_LV_UK = df_LV_UK[df_LV_UK['full_price'] >= 200000]
highest_value_product_LV_UK.groupby(['category2_code']).agg({"full_price": "mean"})
# Out:
#                    full_price
# category2_code
# TRUNKS AND TRAVEL    218000.0

# %%
# checking average price per category
avg_price_per_category = df_LV_Canada.groupby(['category2_code']).agg({"full_price": "mean", "price": "count", "category2_code" : "count"})

#sorting it
avg_price_per_category_sorted = avg_price_per_category.sort_values(by='full_price', ascending=True)
avg_price_per_category_sorted
# Out:
#                                 full_price  price  category2_code
# category2_code
# BOOKS AND STATIONERY            201.315000    200             200
# GIFT SELECTION FOR MEN          675.454545     11              11
# FASHION JEWELRY                 746.624606    317             317
# ACCESSORIES                     782.038043    920             920
# GIFT SELECTION FOR WOMEN       1159.166667     54              54
# GIFTS FOR BABY                 1227.941176     68              68
# TECHNICAL CASES                1280.000000      4               4
# SMALL LEATHER GOODS            1427.639373    574             574
# SHOES                          1600.938776    735             735
# NEW FORMAL                     1615.476190     84              84
# LOUIS VUITTON COLORMANIA       1651.500000     16              16
# WALLETS                        2246.323529     34              34
# LV SKI                         2333.714286     70              70
# FOR WOMEN                      2785.556541    451             451
# FOR MEN                        3108.840671    477             477
# FOR HIM                        3347.222222     18              18
# TRAVEL                         3732.102804    107             107
# TECH OBJECTS AND ACCESSORIES   3748.620690     29              29
# BAGS                           3963.863636     44              44
# READY TO WEAR                  4027.260243   2221            2221
# HANDBAGS                       4624.353120    657             657
# MENS BAGS                      4650.793651     63              63
# CATEGORIES                     8284.482759     29              29
# WATCHES AND JEWELRY            8439.527027     74              74
# TRADITIONAL WATCHES            9199.528302     53              53
# COLLECTIONS                   12862.976744    215             215
# TRUNKS AND TRAVEL             19875.968858    289             289
# HIGHLIGHTS                    20019.680851     94              94
# HOME                          21294.071429    140             140
# SPORTS AND LIFESTYLE          21619.029126    103             103

# %%
# checking average price per category
avg_price_per_category_UK = df_LV_UK.groupby(['category2_code']).agg({"full_price": "mean", "price": "count", "category2_code" : "count"})

#sorting it
avg_price_per_category_sorted_UK = avg_price_per_category_UK.sort_values(by='full_price', ascending=True)
avg_price_per_category_sorted_UK
# Out:
#                                      full_price  price  category2_code
# category2_code
# CONNECTED WATCHES                    300.000000      5               5
# BOOKS AND STATIONERY                 331.552239    268             268
# FASHION JEWELLERY                    449.988038    418             418
# ACCESSORIES                          456.971757    956             956
# GIFT SELECTION FOR MEN               461.466667     15              15
# GIFTS FOR HER                        650.471698    106             106
# GIFTS FOR BABY                       690.447761     67              67
# WALLETS AND SMALL LEATHER GOODS      822.059259    675             675
# SHOES                                961.332863    709             709
# LOUIS VUITTON COLOURMANIA           1083.390244     41              41
# NEW FORMAL                          1117.654867    113             113
# FOR MEN                             1446.632653    294             294
# LV SKI                              1806.580357    112             112
# FOR WOMEN                           2215.766667    300             300
# TRAVEL                              2272.068966     58              58
# READY TO WEAR                       2368.369444   1800            1800
# SPORT AND LIFESTYLE                 2625.060976     82              82
# BAGS                                2674.761905     84              84
# HANDBAGS                            2697.537879    528             528
# HIGH TECH OBJECTS AND ACCESSORIES   3246.666667     27              27
# TRADITIONAL WATCHES                 4687.169231     65              65
# CATEGORIES                          5262.414966    147             147
# COLLECTIONS                         7660.120482    249             249
# HOME                               10457.371134    194             194
# HIGHLIGHTS                         10508.328571    140             140
# TRUNKS AND TRAVEL                  13611.736111    288             288

# %%
#CHECKING CATERGORY 1
unique_category1_lv_canada = df_LV_Canada["category1_code"].unique()
print("Unique Category1 LV Canada:" , sorted(unique_category1_lv_canada))

unique_category1_lv_uk = df_LV_UK["category1_code"].unique()
print("Unique Category1 LV UK:" ,sorted(unique_category1_lv_uk))
# Out:
# Unique Category1 LV Canada: ['ART OF LIVING', 'GIFTS', 'JEWELRY', 'MEN', 'NEW', 'PERFUMES', 'WATCHES', 'WOMEN']
# Unique Category1 LV UK: ['ART OF LIVING', 'BAGS', 'GIFTS', 'JEWELLERY', 'MEN', 'NEW', 'PERFUMES', 'WATCHES', 'WOMEN']

# %%
#CHECKING CATERGORY 2
unique_category2_lv_canada = df_LV_Canada["category2_code"].unique()
print("Unique Category2 LV Canada:" , sorted(unique_category2_lv_canada))

unique_category2_lv_uk = df_LV_UK["category2_code"].unique()
print("Unique Category2 LV UK:" ,sorted(unique_category2_lv_uk))
# Out:
# Unique Category2 LV Canada: ['ACCESSORIES', 'BAGS', 'BOOKS AND STATIONERY', 'CATEGORIES', 'COLLECTIONS', 'FASHION JEWELRY', 'FOR HIM', 'FOR MEN', 'FOR WOMEN', 'GIFT SELECTION FOR MEN', 'GIFT SELECTION FOR WOMEN', 'GIFTS FOR BABY', 'HANDBAGS', 'HIGHLIGHTS', 'HOME', 'LOUIS VUITTON COLORMANIA', 'LV SKI', 'MENS BAGS', 'NEW FORMAL', 'READY TO WEAR', 'SHOES', 'SMALL LEATHER GOODS', 'SPORTS AND LIFESTYLE', 'TECH OBJECTS AND ACCESSORIES', 'TECHNICAL CASES', 'TRADITIONAL WATCHES', 'TRAVEL', 'TRUNKS AND TRAVEL', 'WALLETS', 'WATCHES AND JEWELRY']
# Unique Category2 LV UK: ['ACCESSORIES', 'BAGS', 'BOOKS AND STATIONERY', 'CATEGORIES', 'COLLECTIONS', 'CONNECTED WATCHES', 'FASHION JEWELLERY', 'FOR MEN', 'FOR WOMEN', 'GIFT SELECTION FOR MEN', 'GIFTS FOR BABY', 'GIFTS FOR HER', 'HANDBAGS', 'HIGH TECH OBJECTS AND ACCESSORIES', 'HIGHLIGHTS', 'HOME', 'LOUIS VUITTON COLOURMANIA', 'LV SKI', 'NEW FORMAL', 'READY TO WEAR', 'SHOES', 'SPORT AND LIFESTYLE', 'TRADITIONAL WATCHES', 'TRAVEL', 'TRUNKS AND TRAVEL', 'WALLETS AND SMALL LEATHER GOODS']

# %%
# Get unique category2 codes for Canada and the UK
unique_category2_lv_canada = df_LV_Canada["category2_code"].unique()
unique_category2_lv_uk = df_LV_UK["category2_code"].unique()

# Determine the maximum length of the unique category codes
max_length = max(len(unique_category2_lv_canada), len(unique_category2_lv_uk))

# Pad the shorter list with z_Null strings at the end to make them equal in length
unique_category2_lv_canada_padded = list(unique_category2_lv_canada) + ['z_Null'] * (max_length - len(unique_category2_lv_canada))
unique_category2_lv_uk_padded = list(unique_category2_lv_uk) + ['z_Null'] * (max_length - len(unique_category2_lv_uk))

# Create a DataFrame to hold the unique values
df_unique_categories = pd.DataFrame({
    "Unique Category2 LV Canada": sorted(unique_category2_lv_canada_padded),
    "Unique Category2 LV UK": sorted(unique_category2_lv_uk_padded)
})

# Print the DataFrame
print(df_unique_categories)
# Out:
#       Unique Category2 LV Canada             Unique Category2 LV UK
# 0                    ACCESSORIES                        ACCESSORIES
# 1                           BAGS                               BAGS
# 2           BOOKS AND STATIONERY               BOOKS AND STATIONERY
# 3                     CATEGORIES                         CATEGORIES
# 4                    COLLECTIONS                        COLLECTIONS
# 5                FASHION JEWELRY                  CONNECTED WATCHES
# 6                        FOR HIM                  FASHION JEWELLERY
# 7                        FOR MEN                            FOR MEN
# 8                      FOR WOMEN                          FOR WOMEN
# 9         GIFT SELECTION FOR MEN             GIFT SELECTION FOR MEN
# 10      GIFT SELECTION FOR WOMEN                     GIFTS FOR BABY
# 11                GIFTS FOR BABY                      GIFTS FOR HER
# 12                      HANDBAGS                           HANDBAGS
# 13                    HIGHLIGHTS  HIGH TECH OBJECTS AND ACCESSORIES
# 14                          HOME                         HIGHLIGHTS
# 15      LOUIS VUITTON COLORMANIA                               HOME
# 16                        LV SKI          LOUIS VUITTON COLOURMANIA
# 17                     MENS BAGS                             LV SKI
# 18                    NEW FORMAL                         NEW FORMAL
# 19                 READY TO WEAR                      READY TO WEAR
# 20                         SHOES                              SHOES
# 21           SMALL LEATHER GOODS                SPORT AND LIFESTYLE
# 22          SPORTS AND LIFESTYLE                TRADITIONAL WATCHES
# 23  TECH OBJECTS AND ACCESSORIES                             TRAVEL
# 24               TECHNICAL CASES                  TRUNKS AND TRAVEL
# 25           TRADITIONAL WATCHES    WALLETS AND SMALL LEATHER GOODS
# 26                        TRAVEL                             z_Null
# 27             TRUNKS AND TRAVEL                             z_Null
# 28                       WALLETS                             z_Null
# 29           WATCHES AND JEWELRY                             z_Null

# %%
# Get unique category2 codes for Canada and the UK
unique_category3_lv_canada = df_LV_Canada["category3_code"].unique()
unique_category3_lv_uk = df_LV_UK["category3_code"].unique()

# Determine the maximum length of the unique category codes
max_length = max(len(unique_category3_lv_canada), len(unique_category3_lv_uk))

# Pad the shorter list with empty strings at the end to make them equal in length
unique_category3_lv_canada_padded = list(unique_category3_lv_canada) + ['z_Null'] * (max_length - len(unique_category3_lv_canada))
unique_category3_lv_uk_padded = list(unique_category3_lv_uk) + ['z_Null'] * (max_length - len(unique_category3_lv_uk))

# Create a DataFrame to hold the unique values
df_unique_categories = pd.DataFrame({
    "Unique Category3 LV Canada": sorted(unique_category3_lv_canada_padded),
    "Unique Category3 LV UK": sorted(unique_category3_lv_uk_padded)
})

# Print the DataFrame
print(df_unique_categories)
# Out:
#          Unique Category3 LV Canada       Unique Category3 LV UK
# 0    ACCESSORIES SEASONAL SELECTION        ALL FASHION JEWELLERY
# 1                          ALL BAGS           ALL FINE JEWELLERY
# 2               ALL FASHION JEWELRY  ALL LUGGAGE AND ACCESSORIES
# 3                  ALL FINE JEWELRY                 ALL PERFUMES
# 4                      ALL HANDBAGS            ALL READY TO WEAR
# ..                              ...                          ...
# 136                           TWIST                       z_Null
# 137     VIVIENNE HOLIDAY COLLECTION                       z_Null
# 138                    WATCH STRAPS                       z_Null
# 139                  WINTER TEXTILE                       z_Null
# 140                               _                       z_Null
#
# [141 rows x 2 columns]

# %%
#checking null values
null_count_in_category1 = df_LV_Canada["category1_code"].isnull().sum()
print("Count of null values in the 'category1' column of LV Canada:", null_count_in_category1)
null_count_in_category1_uk = df_LV_UK["category1_code"].isnull().sum()
print("Count of null values in the 'category1' column of LV UK:", null_count_in_category1_uk)

null_count_in_category2 = df_LV_Canada["category2_code"].isnull().sum()
print("Count of null values in the 'category2' column of LV Canada:", null_count_in_category2)
null_count_in_category2_uk = df_LV_UK["category2_code"].isnull().sum()
print("Count of null values in the 'category2' column of LV UK:", null_count_in_category2_uk)

null_count_in_category3 = df_LV_Canada["category3_code"].isnull().sum()
print("Count of null values in the 'category3' column of LV Canada:", null_count_in_category3)
null_count_in_category3_uk = df_LV_UK["category3_code"].isnull().sum()
print("Count of null values in the 'category1' column of LV UK:", null_count_in_category3_uk)
# Out:
# Count of null values in the 'category1' column of LV Canada: 0
# Count of null values in the 'category1' column of LV UK: 0
# Count of null values in the 'category2' column of LV Canada: 0
# Count of null values in the 'category2' column of LV UK: 0
# Count of null values in the 'category3' column of LV Canada: 0
# Count of null values in the 'category1' column of LV UK: 0

# %%
#Category Mapping
category_mapping = {
    'SHOES': ['SHOES'],
    'ACCESSORIES/FRAGRANCES': ['ACCESSORIES', 'FASHION JEWELRY', 'SMALL LEATHER GOODS', 
                    'TECH OBJECTS AND ACCESSORIES', 'TECHNICAL CASES', 'COLLECTIONS', 'HIGH TECH OBJECTS AND ACCESSORIES', 'WALLETS AND SMALL LEATHER GOODS'],
    'BAGS': ['BAGS', 'HANDBAGS', 'MENS BAGS', 'WALLETS'],
    'WATCHES': ['TRADITIONAL WATCHES', 'WATCHES AND JEWELRY', 'CONNECTED WATCHES'],
    'CLOTHING': ['NEW FORMAL', 'READY TO WEAR'],
    'ALL':    ['FOR HIM', 'FOR MEN', 'FOR WOMEN',], 
    'GIFTS':    ['GIFT SELECTION FOR MEN', 
                 'GIFT SELECTION FOR WOMEN', 'GIFTS FOR BABY', 'GIFTS FOR HER'],
    'DECOR/HOME': ['BOOKS AND STATIONERY', 'HOME',
                   'LV SKI'],
    'MAKEUP': [],  # No data
    'TRAVEL': ['TRAVEL', 'TRUNKS AND TRAVEL','LOUIS VUITTON COLORMANIA'],
    'OTHER': ['CATEGORIES', 'HIGHLIGHTS', 'SPORTS AND LIFESTYLE', 'SPORT AND LIFESTYLE']
}

# Function to assign category based on category2_code
def assign_category(category):
    for label, associated_categories in category_mapping.items():
        if category in associated_categories:
            return label
    return None

# Add 'Category' column to the DataFrame df_LV_canada
df_LV_Canada['Category'] = df_LV_Canada['category2_code'].apply(assign_category)

# Add 'Category' column to the DataFrame df_LV_UK
df_LV_UK['Category'] = df_LV_UK['category2_code'].apply(assign_category)

# %%
# checking what comes under collection

collections_df = df_LV_Canada[df_LV_Canada['category2_code'] == 'COLLECTIONS']

# Check unique values of category2 in the filtered DataFrame
unique_category2_collections = collections_df['category1_code'].unique()

print("Unique values of category2 when category1 is 'Perfumes':", unique_category2_collections)
# Out:
# Unique values of category2 when category1 is 'Perfumes': ['JEWELRY' 'PERFUMES']

# %%
# group mapping LV Canada
group_mapping = {
    'MEN': ['MEN'],
    'WOMEN': ['WOMEN'],
    'OTHER/GENDER NEUTRAL': ['ART OF LIVING', 'GIFTS', 'JEWELRY', 'NEW', 'PERFUMES', 'WATCHES', 'BAGS']
}

# Function to assign group based on category1_code
def assign_group(category):
    for label, associated_categories in group_mapping.items():
        if category in associated_categories:
            return label
    return None

# Add 'Group' column to the DataFrame df_LV_canada
df_LV_Canada['Group'] = df_LV_Canada['category1_code'].apply(assign_group)

# Add 'Group' column to the DataFrame df_LV_UK
df_LV_UK['Group'] = df_LV_UK['category1_code'].apply(assign_group)

# %%
df_LV_Canada
# Out:
#        website_name competence_date country_code currency_code          brand  \
# 0     Louis Vuitton      2023-11-17          CAN           CAD  LOUIS VUITTON
# 1     Louis Vuitton      2023-11-17          CAN           CAD  LOUIS VUITTON
# 2     Louis Vuitton      2023-11-17          CAN           CAD  LOUIS VUITTON
# 3     Louis Vuitton      2023-11-17          CAN           CAD  LOUIS VUITTON
# 4     Louis Vuitton      2023-11-17          CAN           CAD  LOUIS VUITTON
# ...             ...             ...          ...           ...            ...
# 8146  Louis Vuitton      2023-11-17          CAN           CAD  LOUIS VUITTON
# 8147  Louis Vuitton      2023-11-17          CAN           CAD  LOUIS VUITTON
# 8148  Louis Vuitton      2023-11-17          CAN           CAD  LOUIS VUITTON
# 8149  Louis Vuitton      2023-11-17          CAN           CAD  LOUIS VUITTON
# 8150  Louis Vuitton      2023-11-17          CAN           CAD  LOUIS VUITTON
#
#      category1_code category2_code                category3_code  \
# 0             WOMEN          SHOES                      SNEAKERS
# 1             WOMEN    ACCESSORIES                THE ESSENTIALS
# 2             WOMEN       HANDBAGS                         TWIST
# 3             WOMEN       HANDBAGS  SHOULDER AND CROSS BODY BAGS
# 4               NEW      FOR WOMEN               NEW THIS SEASON
# ...             ...            ...                           ...
# 8146          WOMEN    ACCESSORIES                         BELTS
# 8147          WOMEN       HANDBAGS  SHOULDER AND CROSS BODY BAGS
# 8148         2996.63    2996.63             0                    BAGS
# 8149         2558.92    2558.92             0                    BAGS
# 8150         2323.23    2323.23             0                    BAGS
#
#                      Group
# 0                    WOMEN
# 1                    WOMEN
# 2                    WOMEN
# 3                    WOMEN
# 4     OTHER/GENDER NEUTRAL
# ...                    ...
# 8146                 WOMEN
# 8147                 WOMEN
# 8148                 WOMEN
# 8149                 WOMEN
# 8150                 WOMEN
#
# [8151 rows x 19 columns]

# %%
df_LV_UK
# Out:
#        website_name competence_date country_code currency_code          brand  \
# 0     Louis Vuitton      2023-11-17          GBR           GBP  LOUIS VUITTON
# 1     Louis Vuitton      2023-11-17          GBR           GBP  LOUIS VUITTON
# 2     Louis Vuitton      2023-11-17          GBR           GBP  LOUIS VUITTON
# 3     Louis Vuitton      2023-11-17          GBR           GBP  LOUIS VUITTON
# 4     Louis Vuitton      2023-11-17          GBR           GBP  LOUIS VUITTON
# ...             ...             ...          ...           ...            ...
# 7736  Louis Vuitton      2023-11-17          GBR           GBP  LOUIS VUITTON
# 7737  Louis Vuitton      2023-11-17          GBR           GBP  LOUIS VUITTON
# 7738  Louis Vuitton      2023-11-17          GBR           GBP  LOUIS VUITTON
# 7739  Louis Vuitton      2023-11-17          GBR           GBP  LOUIS VUITTON
# 7740  Louis Vuitton      2023-11-17          GBR           GBP  LOUIS VUITTON
#
#      category1_code       category2_code                     category3_code  \
# 0               MEN        READY TO WEAR                           TROUSERS
# 1             WOMEN          ACCESSORIES                  SHAWLS AND STOLES
# 2             WOMEN        READY TO WEAR                  ALL READY TO WEAR
# 3             GIFTS  SPORT AND LIFESTYLE       LIFESTYLE AND VIVIENNE DOLLS
# 4             WOMEN                SHOES                           SNEAKERS
# ...             ...                  ...                                ...
# 7736            MEN                 BAGS               ICONIC MONOGRAM BAGS
# 7737            MEN    TRUNKS AND TRAVEL  TRAVEL ACCESSORIES AND ORGANISERS
# 7738            MEN                 BAGS               ICONIC MONOGRAM BAGS
# 7739          WOMEN                SHOES                          ALL SHOES
# 7740          WOMEN                SHOES                              PUMPS
#
#                product_code                           title  \
# 0     NVPROD3760097V/1AAGV0                 Tailored Shorts
# 1     NVPROD3760189V/M77702  Braided Monogram Printed Shawl
# 2     NVPROD3770049V/1AAF90              Preppy Wool Blazer
# 3     NVPROD3780048V/GI0798             Thomas Œnologie Kit
# 4     NVPROD3800029V/1AAP61                 Run 55 Trainers
# ...                     ...                             ...
# 7736  NVPROD4430128V/M46688            S-Lock Messenger Bag
# 7737  NVPROD4430133V/M46696           Dopp Kit Toiletry Bag
# 7738  NVPROD4430134V/M46699         Christopher PM Backpack
# 7739  NVPROD4830138V/1ACIT1              Stellar Slingbacks
# 7740  NVPROD4830138V/1ACITB              Stellar Slingbacks
#
#                                                 itemurl  \
# 0     https://uk.louisvuitton.com/eng-gb/products/ta...
# 1     https://uk.louisvuitton.com/eng-gb/products/br...
# 2     https://uk.louisvuitton.com/eng-gb/products/pr...
# 3     https://uk.louisvuitton.com/eng-gb/products/th...
# 4     https://uk.louisvuitton.com/eng-gb/products/ru...
# ...                                                 ...
# 7736  https://uk.louisvuitton.com/eng-gb/products/s-...
# 7737  https://uk.louisvuitton.com/eng-gb/products/do...
# 7738  https://uk.louisvuitton.com/eng-gb/products/ch...
# 7739  https://uk.louisvuitton.com/eng-gb/products/st...
# 7740  https://uk.louisvuitton.com/eng-gb/products/st...
#
#                                                imageurl  full_price   price  \
# 0     https://uk.louisvuitton.com/images/is/image/lv...       990.0   990.0
# 1     https://uk.louisvuitton.com/images/is/image/lv...       565.0   565.0
# 2     https://uk.louisvuitton.com/images/is/image/lv...      2440.0  2440.0
# 3     https://uk.louisvuitton.com/images/is/image/lv...      1790.0  1790.0
# 4     https://uk.louisvuitton.com/images/is/image/lv...       930.0   930.0
# ...                                                 ...         ...     ...
# 7736  https://uk.louisvuitton.com/images/is/image/lv...      2200.0  2200.0
# 7737  https://uk.louisvuitton.com/images/is/image/lv...       735.0   735.0
# 7738  https://uk.louisvuitton.com/images/is/image/lv...      2430.0  2430.0
# 7739  https://uk.louisvuitton.com/images/is/image/lv...       860.0   860.0
# 7740  https://uk.louisvuitton.com/images/is/image/lv...       860.0   860.0
#
#       full_price_eur  price_eur  flg_discount                Category  \
# 0            1131.42    1131.42             0                CLOTHING
# 1             645.71     645.71             0  ACCESSORIES/FRAGRANCES
# 2            2788.57    2788.57             0                CLOTHING
# 3            2045.71    2045.71             0                   OTHER
# 4            1062.85    1062.85             0                   SHOES
# ...              ...        ...           ...                     ...
# 7736         2514.28    2514.28             0                    BAGS
# 7737          840.00     840.00             0                  TRAVEL
# 7738         2777.14    2777.14             0                    BAGS
# 7739          982.85     982.85             0                   SHOES
# 7740          982.85     982.85             0                   SHOES
#
#                      Group
# 0                      MEN
# 1                    WOMEN
# 2                    WOMEN
# 3     OTHER/GENDER NEUTRAL
# 4                    WOMEN
# ...                    ...
# 7736                   MEN
# 7737                   MEN
# 7738                   MEN
# 7739                 WOMEN
# 7740                 WOMEN
#
# [7741 rows x 19 columns]

# %%
#Some basic stats

bags_df = df_LV_Canada[df_LV_Canada['Category'] == 'BAGS']


# Create scatter plot of price versus category3
plt.figure(figsize=(10, 6))
plt.scatter(bags_df['category3_code'], bags_df['full_price_eur'], color='blue', alpha=0.7)
plt.xlabel('Category 3')
plt.ylabel('Price in Euro')
plt.title('Scatter Plot of Price versus Category 3 for Bags')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()

# %%
#Should we convert all prices to USD???

#or check full price euro???

bags_df_UK = df_LV_UK[df_LV_UK['Category'] == 'BAGS']


# Create scatter plot of price versus category3
plt.figure(figsize=(10, 6))
plt.scatter(bags_df_UK['category3_code'], bags_df_UK['full_price_eur'], color='blue', alpha=0.7)
plt.xlabel('Category 3')
plt.ylabel('Price in Euro')
plt.title('Scatter Plot of Price versus Category 3 for Bags')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()
